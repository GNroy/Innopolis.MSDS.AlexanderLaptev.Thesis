# %%
from os.path import join as dir_join
from os.path import exists as dir_exists
from os import makedirs, listdir
import re
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import time
from itertools import combinations
from sklearn.model_selection import KFold
from sklearn.metrics import precision_recall_fscore_support
from IPython.core import display as ICD

from utills import Candidate, Platoon
from pattern_miner import Miner

import warnings
import sklearn.exceptions
warnings.filterwarnings("ignore", category=sklearn.exceptions.UndefinedMetricWarning)

def get_trajectory_id(text):
    m = re.search('client_(.+).csv', text)
    if m:
        found = m.group(1)
        return found
    else:
        raise ValueError()

TRAJ_FOLDER = 'paths'
columns = ['lat', 'long', 'datetime', 'trajectory_id']
FILE_NAME = dir_join(TRAJ_FOLDER, 'processed.csv')

if not dir_exists(FILE_NAME):
    if not dir_exists(TRAJ_FOLDER):
        raise ValueError(TRAJ_FOLDER + ' does not exist')
    folder_files = istdir(TRAJ_FOLDER)
    list_df = []
    for filename in folder_files:
        df = pd.read_csv(dir_join(TRAJ_FOLDER, filename), names=columns)
        df['datetime'] = pd.to_datetime(df['datetime'], unit='s')
        df['trajectory_id'] = get_trajectory_id(filename)
        list_df += [df]
    df = pd.concat(list_df, ignore_index=True)
    df.to_csv(FILE_NAME, index=False)

df = pd.read_csv(FILE_NAME, parse_dates=[columns.index('datetime')], dtype={'lat': np.float32, 'long': np.float32, 'trajectory_id': np.str_})
df.head()
# Out:
#      lat   long            datetime trajectory_id
# 0  359.5  416.5 2017-12-21 13:01:42          4976
# 1  359.5  416.5 2017-12-21 13:01:49          4976
# 2  359.5  416.5 2017-12-21 13:01:54          4976
# 3  364.5  426.5 2017-12-21 13:01:59          4976
# 4  379.5  456.5 2017-12-21 13:02:06          4976

# %%
savefolder = 'results_large'
if not dir_exists(savefolder):
    makedirs(savefolder)

sampling_interval = pd.Timedelta(minutes=1)
split_border = pd.Timedelta(days=1)
max_time_interval = df['datetime'].max()-df['datetime'].min()
pl = Platoon(2, 60, 5, max_time_interval // sampling_interval)
miner = Miner(df, pl, sampling_interval)

time1 = time.time()
print('Start time: ' + time.ctime())
#miner.extract_staypoints_heatmap(10)
#miner.save_staypoints_heatmap(dir_join(savefolder, 'staypoints_heatmap.npy'))
miner.load_staypoints_heatmap(dir_join(savefolder, 'staypoints_heatmap.npy'))
time2 = time.time()
print('Staypoints extraction done. Time: ' + str(time2 - time1))
miner.unify_datetime(split_border)
time3 = time.time()
print('Data unification done. Time: ' + str(time3 - time2))
#miner.compute_candidate_stars(5)
#miner.save_candidate_stars(dir_join(savefolder, 'candidate_stars.json'))
miner.load_candidate_stars(dir_join(savefolder, 'candidate_stars.json'))
time4 = time.time()
print('Candidate stars computing done. Time: ' + str(time4 - time3))
miner.compute_pattern_set()
time5 = time.time()
print('Pattern set computing done. Time: ' + str(time5 - time4))
#miner.compute_connection_rate()
#miner.save_connection_rate(dir_join(savefolder, 'connection_rate.npz'))
miner.load_connection_rate(dir_join(savefolder, 'connection_rate.npz'))
time6 = time.time()
print('Connection rate computing done. Time: ' + str(time6 - time5))
print('All time: ' + str(time6 - time1))
print('Finish time: ' + time.ctime())
# Out:
# Start time: Sat May 12 15:48:48 2018
# Staypoints extraction done. Time: 0.011251211166381836
# Data unification done. Time: 206.62967610359192
# Candidate stars computing done. Time: 0.1656208038330078
# Pattern set computing done. Time: 8.089789628982544
# Connection rate computing done. Time: 0.00606083869934082
# All time: 214.9023985862732
# Finish time: Sat May 12 15:52:23 2018

# %%
userinfo = pd.read_csv('user_info.csv', parse_dates=['userinfo_dateofbirth'], dtype={'userinfo_sso': np.str_}).fillna('not_set')
bins = pd.date_range(userinfo['userinfo_dateofbirth'].min() - pd.Timedelta(days=365), pd.to_datetime('today'), freq='10Y')
bins = bins[[0,3]+list(range(6,len(bins)))] # drop redundant
userinfo['dateofbirth_cat'] = pd.cut(userinfo['userinfo_dateofbirth'], bins, labels=[str(bins[i-1].year)+'-'+str(bins[i].year) for i in range(1, len(bins))])

race_cut = {}
race_cut['GreaterEuropean,WestEuropean,Italian'] = 'Italian'
race_cut['GreaterEuropean,WestEuropean,Germanic'] = 'Germanic'
race_cut['GreaterEuropean,WestEuropean,Nordic'] = 'Nordic'
race_cut['GreaterEuropean,British'] = 'British'
race_cut['GreaterAfrican,Africans'] = 'Africans'
race_cut['Asian,GreaterEastAsian,EastAsian'] = 'EastAs'
race_cut['GreaterEuropean,WestEuropean,French'] = 'French'
race_cut['GreaterEuropean,EastEuropean'] = 'EastEu'
race_cut['GreaterEuropean,WestEuropean,Hispanic'] = 'Hispanic'
race_cut['GreaterAfrican,Muslim'] = 'Muslim'
race_cut['GreaterEuropean,Jewish'] = 'Jewish'
race_cut['Asian,IndianSubContinent'] = 'Indian'
race_cut['Asian,GreaterEastAsian,Japanese'] = 'Japanese'
userinfo['race'] = userinfo['race'].apply(lambda x: race_cut[x])

userinfo.head()
# Out:
#   userinfo_sso userinfo_dateofbirth userinfo_language      race  Gender  \
# 0            1           1970-01-01                de   Italian    male
# 1            5           1984-11-01                en   Italian    male
# 2           13           1970-01-01                de  Germanic    male
# 3           25           1961-09-23                en   Italian  female
# 4           28           1965-10-15                en  Germanic    male
#
#   dateofbirth_cat
# 0       1969-1979
# 1       1979-1989
# 2       1969-1979
# 3       1939-1969
# 4       1939-1969

# %%
savefolder_userinfo = dir_join(savefolder, 'userinfo_hist')
if not dir_exists(savefolder_userinfo):
    makedirs(savefolder_userinfo)

cat_cols = ['userinfo_language', 'race', 'Gender', 'dateofbirth_cat']
G = miner.graph()
for column_name in cat_cols:
    for i in G:
        column = userinfo[userinfo['userinfo_sso'].isin(list(G.neighbors(i)))][column_name]
        pd.Series(dict((y, x) for x, y in np.array(np.unique(column, return_counts=True))[::-1].T)).plot(kind='bar')
        plt.title(' '.join([column_name, 'Person', str(i)]))
        plt.tight_layout()
        plt.savefig(dir_join(savefolder_userinfo, '.'.join([str(i), column_name, 'png'])))
        plt.clf()
    column = userinfo[column_name]
    pd.Series(dict((y, x) for x, y in np.array(np.unique(column, return_counts=True))[::-1].T)).plot(kind='bar')
    plt.title(' '.join([column_name, 'All']))
    plt.tight_layout()
    plt.savefig(dir_join(savefolder_userinfo, '.'.join([column_name, 'All', 'png'])))
    plt.clf()

# %%
savefolder_unary = dir_join(savefolder, 'unary_hist')
if not dir_exists(savefolder_unary):
    makedirs(savefolder_unary)

cat_cols = ['userinfo_language', 'race', 'Gender', 'dateofbirth_cat']
G = miner.graph()
for column_name in cat_cols:
    values_dict = {}
    for value in userinfo[column_name].unique():
        values_dict[value] = pd.Series()
    for i in G:
        value = userinfo[userinfo['userinfo_sso']==i][column_name].iloc[0]
        column = userinfo[userinfo['userinfo_sso'].isin(list(G.neighbors(i)))][column_name]
        if(len(column) > 0):
            values_dict[value] = values_dict[value].add(column.value_counts(normalize=True), fill_value=0)
    for value in values_dict:
        if(len(values_dict[value]) > 0):
            values_dict[value].plot(kind='bar')
            plt.title(' '.join([column_name, value]))
            plt.tight_layout()
            plt.savefig(dir_join(savefolder_unary, '.'.join([column_name, value, 'png'])))
            plt.clf()
        else:
            print(' '.join(['Value', value, 'skipped']))

# %%
savefolder_binary = dir_join(savefolder, 'binary_hist')
if not dir_exists(savefolder_binary):
    makedirs(savefolder_binary)

cat_cols = ['userinfo_language', 'race', 'Gender', 'dateofbirth_cat']
G = miner.graph()
for column_name in combinations(cat_cols, 2):
    column_name_list = list(column_name)
    values_dict = {}
    for value in userinfo[column_name_list].groupby(column_name_list).count().reset_index().values:
        values_dict[tuple(value)] = pd.Series()
    for i in G:
        value = tuple(userinfo[userinfo['userinfo_sso']==i][column_name_list].values[0])
        columns = userinfo[userinfo['userinfo_sso'].isin(list(G.neighbors(i)))][column_name_list].groupby(column_name_list).size()
        columns /= columns.sum()
        if(len(columns) > 0):
            values_dict[value] = values_dict[value].add(columns, fill_value=0) if len(values_dict[value]) > 0 else columns
    for value in values_dict:
        if(len(values_dict[value]) > 0):
            values_dict[value].plot(kind='bar')
            plt.title(' '.join([' '.join(column_name), ' '.join(value)]))
            plt.tight_layout()
            plt.savefig(dir_join(savefolder_binary, '.'.join(['_'.join(column_name), '_'.join(value), 'png'])))
            plt.clf()
        else:
            print(' '.join(['Value', ' '.join(value), 'skipped']))
# Out:
# Value de Italian skipped
# Value de Nordic skipped
# Value it EastEu skipped
# Value it French skipped
# Value it not_set skipped
# Value de 1909-1939 skipped
# Value de 1979-1989 skipped
# Value it 1909-1939 skipped
# Value it 1999-2009 skipped
# Value Africans male skipped
# Value EastAs male skipped
# Value Hispanic female skipped
# Value Nordic female skipped
# Value Africans 1909-1939 skipped
# Value Africans 1939-1969 skipped
# Value Africans 1999-2009 skipped
# Value EastAs 1909-1939 skipped
# Value EastAs 1939-1969 skipped
# Value EastAs 1989-1999 skipped
# Value EastAs 1999-2009 skipped
# Value EastEu 1909-1939 skipped
# Value EastEu 1979-1989 skipped
# Value EastEu 1999-2009 skipped
# Value French 1909-1939 skipped
# Value French 1999-2009 skipped
# Value Hispanic 1909-1939 skipped
# Value Hispanic 1979-1989 skipped
# Value Hispanic 1999-2009 skipped
# Value Indian 1909-1939 skipped
# Value Indian 1939-1969 skipped
# Value Indian 1979-1989 skipped
# Value Italian 1909-1939 skipped
# Value Japanese 1909-1939 skipped
# Value Japanese 1939-1969 skipped
# Value Japanese 1979-1989 skipped
# Value Japanese 1999-2009 skipped
# Value Jewish 1909-1939 skipped
# Value Jewish 1979-1989 skipped
# Value Muslim 1909-1939 skipped
# Value Muslim 1939-1969 skipped
# Value Nordic 1909-1939 skipped
# Value Nordic 1939-1969 skipped
# Value Nordic 1989-1999 skipped
# Value not_set 1909-1939 skipped

# %%
def get_common_data(df, neighbors, cat_cols, label_col, mode='unary'):
    data_dict = {}
    if mode == 'binary':
        for column_name in combinations(cat_cols, 2):
            column_name_list = list(column_name)
            values_dict = {}
            #unique_values = df[column_name_list].groupby(column_name_list).count().reset_index().values
            unique_values = df[column_name_list].groupby(column_name_list).size().index.tolist()
            for value in unique_values:
                #values_dict[tuple(value)] = pd.Series(index=unique_values).fillna(0)
                values_dict[value] = pd.Series(index=unique_values).fillna(0)
            for i in neighbors:
                value = tuple(df[df[label_col]==i][column_name_list].values[0])
                columns = df[df[label_col].isin(neighbors[i])][column_name_list].groupby(column_name_list).size()
                columns = pd.Series(columns.values / columns.sum(), index=columns.index.tolist())
                if len(columns) > 0:
                    values_dict[value] = values_dict[value].add(columns, fill_value=0)
            for value in values_dict:
                values_dict[value] = values_dict[value] / values_dict[value].sum()
            data_dict[column_name] = values_dict
    elif mode == 'unary':
        for column_name in cat_cols:
            values_dict = {}
            unique_values = df[column_name].unique()
            for value in unique_values:
                values_dict[value] = pd.Series(index=unique_values).fillna(0)
            for i in neighbors:
                value = df[df[label_col]==i][column_name].iloc[0]
                column = df[df[label_col].isin(neighbors[i])][column_name]
                if len(column) > 0:
                    values_dict[value] = values_dict[value].add(column.value_counts(normalize=True), fill_value=0)
            for value in values_dict:
                values_dict[value] = values_dict[value] / values_dict[value].sum()
            data_dict[column_name] = values_dict
    else:
        raise NotImplementedError()
    return data_dict

def get_user_data(df, neighbors, cat_cols, label_col, mode='unary'):
    data_dict = {}
    if mode == 'binary':
        for column_name in combinations(cat_cols, 2):
            column_name_list = list(column_name)
            values_dict = {}
            unique_values = df[column_name_list].groupby(column_name_list).count().reset_index().values
            for i in neighbors:
                values_dict[i] = pd.Series(index=unique_values).fillna(0)
                columns = df[df[label_col].isin(neighbors[i])][column_name_list].groupby(column_name_list).size()
                columns = pd.Series(columns.values / columns.sum(), index=columns.index.tolist())
                if len(columns) > 0:
                    values_dict[i] = values_dict[i].add(columns, fill_value=0)
            data_dict[column_name] = values_dict
    elif mode == 'unary':
        for column_name in cat_cols:
            values_dict = {}
            for i in neighbors:
                values_dict[i] = pd.Series(index=df[column_name].unique()).fillna(0)
                column = df[df[label_col].isin(neighbors[i])][column_name]
                if len(column) > 0:
                    values_dict[i] = values_dict[i].add(column.value_counts(normalize=True), fill_value=0)
            data_dict[column_name] = values_dict
    else:
        raise NotImplementedError()
    return data_dict

def test_prediction(df, G, cat_cols, label_col, n_splits, mode='unary'):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
    X = df[df[label_col].isin(G)]
    score = dict((cat, []) for cat in cat_cols)
    cat_labels = dict((cat, np.sort(df[cat].unique())) for cat in cat_cols)
    score_labels = ['precision', 'recall', 'fscore', 'count']
    for train_index, test_index in kf.split(X):
        # prepare data, make histograms
        X_train, X_test = X.iloc[train_index], X.iloc[test_index]
        neighbors_train = dict((i, list(G.neighbors(i))) for i in G if i in X_train[label_col].values)
        neighbors_test = dict((i, list(G.neighbors(i))) for i in G if i in X_test[label_col].values)
        data_train = get_common_data(X_train, neighbors_train, cat_cols, label_col, mode=mode)
        data_test = get_user_data(X_train, neighbors_test, cat_cols, label_col, mode=mode)
        # get true data
        true_dict = dict((col, pd.Series()) for col in cat_cols)
        for i in X_test.iterrows():
            for col in cat_cols:
                true_dict[col][i[1][label_col]] = i[1][col]
        # make a prediction
        pred_dict = {}
        for cat, persons_dict in data_test.items():
            pred_cat_dict = pd.Series()
            for i in persons_dict:
                deviation = [(value, np.linalg.norm(persons_dict[i] - hist, 1)) for value, hist in data_train[cat].items()]
                pred_cat_dict[i] = min(deviation, key=(lambda item:item[1]))[0]
            pred_dict[cat] = pred_cat_dict
        if mode == 'binary':
            pred_dict_final = {}
            for col in cat_cols:
                pred_cat_dict = pd.Series()
                for i in X_test[label_col]:
                    votes = [pred_dict[cat][i][cat.index(col)] for cat in pred_dict if col in cat]
                    pred_cat_dict[i] = max(votes, key=votes.count)
                pred_dict_final[col] = pred_cat_dict
            pred_dict = pred_dict_final
        # compute the metrics
        for cat in score:
            score[cat] += [precision_recall_fscore_support(true_dict[cat], pred_dict[cat], labels=cat_labels[cat])]
    # make metrics prettier
    for cat in score:
        mean_score = np.mean(score[cat], axis=0)
        mean_score[-1] *= n_splits
        score[cat] = pd.DataFrame(mean_score, index=score_labels, columns=cat_labels[cat]).round(2)
    return score

# %%
n_splits = 10
label_col = 'userinfo_sso'
G = miner.graph()
cat_cols = ['userinfo_language', 'race', 'Gender', 'dateofbirth_cat']
score_unary = test_prediction(userinfo, G, cat_cols, label_col, n_splits, mode='unary')
score_binary = test_prediction(userinfo, G, cat_cols, label_col, n_splits, mode='binary')

savefolder_unary_res = dir_join(savefolder, 'unary_res')
if not dir_exists(savefolder_unary_res):
    makedirs(savefolder_unary_res)

for cat, df in score_unary.items():
    df.to_csv(dir_join(savefolder_unary_res, '.'.join([cat, 'unary', 'csv'])))
    print(' '.join([cat, 'unary']))
    ICD.display(df)
    print()
    print()

savefolder_binary_res = dir_join(savefolder, 'binary_res')
if not dir_exists(savefolder_binary_res):
    makedirs(savefolder_binary_res)

for cat, df in score_binary.items():
    df.to_csv(dir_join(savefolder_binary_res, '.'.join([cat, 'binary', 'csv'])))
    print(' '.join([cat, 'binary']))
    ICD.display(df)
    print()
    print()
# Out:
# userinfo_language unary
#               de      en    it
# precision   0.07    0.85  0.05
# recall      0.15    0.38  0.27
# fscore      0.08    0.50  0.09
# count      16.00  138.00  9.00
# race unary
#            Africans  British  EastAs  EastEu  French  Germanic  Hispanic  \
# precision      0.05     0.08     0.0    0.10     0.0      0.12       0.0
# recall         0.10     0.08     0.0    0.05     0.0      0.06       0.0
# fscore         0.07     0.07     0.0    0.07     0.0      0.07       0.0
# count          5.00    30.00     2.0   13.00     7.0     19.00       6.0
#
#            Indian  Italian  Japanese  Jewish  Muslim  Nordic
# precision    0.10     0.05       0.0    0.05     0.0    0.05
# recall       0.05     0.02       0.0    0.03     0.0    0.05
# fscore       0.07     0.02       0.0    0.04     0.0    0.05
# count       10.00    44.00       2.0   12.00     9.0    4.00
# Gender unary
#            female   male  not_set
# precision    0.32   0.47     0.28
# recall       0.40   0.28     0.52
# fscore       0.32   0.33     0.32
# count       49.00  84.00    30.00
# dateofbirth_cat unary
#            1909-1939  1939-1969  1969-1979  1979-1989  1989-1999  1999-2009
# precision        0.0       0.08       0.20       0.07       0.26       0.10
# recall           0.0       0.05       0.12       0.14       0.16       0.15
# fscore           0.0       0.06       0.15       0.08       0.16       0.12
# count            2.0      34.00      39.00      20.00      54.00      14.00
# userinfo_language binary
#               de      en    it
# precision   0.10    0.93  0.05
# recall      0.65    0.23  0.05
# fscore      0.17    0.35  0.05
# count      16.00  138.00  9.00
# race binary
#            Africans  British  EastAs  EastEu  French  Germanic  Hispanic  \
# precision      0.05     0.15     0.0     0.0     0.0      0.10       0.0
# recall         0.20     0.14     0.0     0.0     0.0      0.03       0.0
# fscore         0.08     0.14     0.0     0.0     0.0      0.05       0.0
# count          5.00    30.00     2.0    13.0     7.0     19.00       6.0
#
#            Indian  Italian  Japanese  Jewish  Muslim  Nordic
# precision    0.50     0.23       0.0    0.20     0.0     0.0
# recall       0.38     0.11       0.0    0.09     0.0     0.0
# fscore       0.42     0.15       0.0    0.12     0.0     0.0
# count       10.00    44.00       2.0   12.00     9.0     4.0
# Gender binary
#            female   male  not_set
# precision    0.33   0.50     0.12
# recall       0.45   0.42     0.12
# fscore       0.35   0.44     0.07
# count       49.00  84.00    30.00
# dateofbirth_cat binary
#            1909-1939  1939-1969  1969-1979  1979-1989  1989-1999  1999-2009
# precision        0.0       0.21        0.0        0.0        0.0        0.0
# recall           0.0       1.00        0.0        0.0        0.0        0.0
# fscore           0.0       0.34        0.0        0.0        0.0        0.0
# count            2.0      34.00       39.0       20.0       54.0       14.0

# %%
import math

def get_mean_std(df, neighbors, cat_cols, label_col, mode='unary'):
    data_dict = {}
    if mode == 'binary':
        for column_name in combinations(cat_cols, 2):
            column_name_list = list(column_name)
            values_dict = {}
            moments_dict = {}
            unique_values = df[column_name_list].groupby(column_name_list).size().index.tolist()
            zero_series = pd.Series(index=unique_values).fillna(0)
            for value in unique_values:
                values_dict[value] = []
            for i in neighbors:
                value = tuple(df[df[label_col]==i][column_name_list].values[0])
                columns = df[df[label_col].isin(neighbors[i])][column_name_list].groupby(column_name_list).size()
                columns = pd.Series(columns.values / columns.sum(), index=columns.index.tolist())
                if len(columns) > 0:
                    values_dict[value] += [zero_series.add(columns, fill_value=0).values]
            for value in values_dict:
                moments_dict[value] = (np.mean(np.array(values_dict[value]), axis=0), np.std(np.array(values_dict[value]), axis=0))
            data_dict[column_name] = moments_dict
    elif mode == 'unary':
        for column_name in cat_cols:
            values_dict = {}
            moments_dict = {}
            unique_values = df[column_name].unique()
            zero_series = pd.Series(index=unique_values).fillna(0)
            for value in unique_values:
                values_dict[value] = []
            for i in neighbors:
                value = df[df[label_col]==i][column_name].iloc[0]
                column = df[df[label_col].isin(neighbors[i])][column_name]
                if len(column) > 0:
                    values_dict[value] += [zero_series.add(column.value_counts(normalize=True), fill_value=0).values]
            for value in values_dict:
                moments_dict[value] = (np.mean(np.array(values_dict[value]), axis=0), np.std(np.array(values_dict[value]), axis=0))
            data_dict[column_name] = moments_dict
    else:
        raise NotImplementedError()
    return data_dict

# %%
label_col = 'userinfo_sso'
G = miner.graph()
cat_cols = ['userinfo_language', 'race', 'Gender', 'dateofbirth_cat']
X = userinfo[userinfo[label_col].isin(G)]
neighbors = dict((i, list(G.neighbors(i))) for i in G)
num = 1
dfs = {}
for mode in ['unary', 'binary']:
    res = get_mean_std(X, neighbors, cat_cols, label_col, mode=mode)
    for cat, val in res.items():
        values = list(val.values())
        N = len(val.keys())
        metric_mat = np.zeros((N, N))
        for i in range(N):
            for j in range(N):
                metric_mat[i, j] = np.linalg.norm(values[i][0] - values[j][0], 1) - num * np.linalg.norm(values[i][1], 1) if i!=j else 1.
        dfs[cat] = pd.DataFrame(metric_mat, index=val.keys(), columns=[str(key) for key in val.keys()]).round(2)
        dfs[cat].to_csv(dir_join(savefolder_unary_res if mode=='unary' else savefolder_binary_res, '.'.join(['metric', str(cat), mode, 'csv'])))
        print(' '.join([str(cat), mode]))
        ICD.display(dfs[cat])
        print()
        print()
# Out:
# userinfo_language unary
#       en    de    it
# en  1.00 -0.63 -0.61
# de -0.57  1.00 -0.35
# it -0.49 -0.30  1.00
# race unary
#           Italian  Germanic  EastAs  British  French  Hispanic  EastEu  \
# Italian      1.00     -1.08   -0.20    -1.29   -1.00     -1.02   -0.99
# Germanic    -1.37      1.00   -0.66    -1.51   -1.36     -1.10   -1.12
# EastAs       0.66      0.48    1.00     0.53    0.58      0.79    0.70
# British     -1.18     -1.12   -0.22     1.00   -0.93     -0.78   -0.85
# French      -0.92     -1.01   -0.21    -0.97    1.00     -0.76   -0.86
# Hispanic    -1.04     -0.83   -0.08    -0.90   -0.84      1.00   -0.81
# EastEu      -0.93     -0.78   -0.10    -0.90   -0.88     -0.73    1.00
# Africans    -0.28     -0.50   -0.10    -0.41   -0.24      0.05   -0.50
# Muslim      -0.82     -0.53    0.10    -0.78   -0.36     -0.40   -0.51
# Jewish      -0.89     -0.67    0.17    -0.80   -0.86     -0.62   -0.60
# Nordic      -0.17     -0.12    0.80    -0.26   -0.16      0.07    0.04
# Indian      -0.60     -0.51    0.18    -0.55   -0.32     -0.28   -0.19
# Japanese     0.01      0.21    0.91     0.07    0.31      0.39    0.31
#
#           Africans  Muslim  Jewish  Nordic  Indian  Japanese
# Italian      -0.67   -1.19   -1.15   -1.12   -1.22     -1.23
# Germanic     -1.17   -1.19   -1.21   -1.35   -1.42     -1.32
# EastAs        0.37    0.58    0.77    0.71    0.42      0.52
# British      -0.69   -1.05   -0.94   -1.10   -1.07     -1.07
# French       -0.56   -0.66   -1.04   -1.04   -0.88     -0.86
# Hispanic     -0.36   -0.79   -0.90   -0.90   -0.92     -0.87
# EastEu       -0.84   -0.82   -0.80   -0.85   -0.76     -0.88
# Africans      1.00   -0.29   -0.14   -0.32   -0.32     -0.43
# Muslim       -0.31    1.00   -0.54   -0.57   -0.70     -0.79
# Jewish       -0.28   -0.66    1.00   -0.70   -0.77     -0.75
# Nordic        0.23    0.00   -0.01    1.00   -0.07     -0.12
# Indian       -0.08   -0.45   -0.40   -0.39    1.00     -0.64
# Japanese      0.42    0.08    0.24    0.17   -0.03      1.00
# Gender unary
#          male  not_set  female
# male     1.00    -0.70   -0.61
# not_set -0.58     1.00   -0.43
# female  -0.54    -0.47    1.00
# dateofbirth_cat unary
#            1979-1989  1969-1979  1909-1939  1939-1969  1989-1999  1999-2009
# 1979-1989       1.00      -0.54       0.02      -0.58      -0.50      -0.53
# 1969-1979      -0.79       1.00      -0.45      -1.06      -0.99      -0.94
# 1909-1939      -0.09      -0.32       1.00      -0.31      -0.30      -0.40
# 1939-1969      -0.55      -0.78      -0.17       1.00      -0.64      -0.67
# 1989-1999      -0.84      -1.08      -0.53      -1.01       1.00      -0.99
# 1999-2009      -0.39      -0.55      -0.14      -0.55      -0.51       1.00
# ('userinfo_language', 'race') binary
#                 ('de', 'Africans')  ('de', 'British')  ('de', 'French')  \
# (de, Africans)                1.00               1.57              1.37
# (de, British)                 0.75               1.00             -0.45
# (de, French)                  1.37               0.37              1.00
# (de, Germanic)                0.01              -0.50             -0.55
# (de, Jewish)                  1.33               1.72              1.66
# (de, Muslim)                  1.67               1.10              1.04
# (en, Africans)                0.61              -0.18             -0.01
# (en, British)                -0.35              -1.46             -1.37
# (en, EastAs)                  0.33               0.39              0.54
# (en, EastEu)                  0.13              -0.96             -0.81
# (en, French)                 -0.32              -1.04             -1.02
# (en, Germanic)               -0.36              -1.41             -1.37
# (en, Hispanic)                0.28              -0.59             -0.67
# (en, Indian)                  0.30              -0.73             -0.73
# (en, Italian)                -0.11              -1.35             -1.26
# (en, Japanese)                1.24               0.09              0.14
# (en, Jewish)                  0.02              -0.97             -1.06
# (en, Muslim)                  0.25              -0.93             -0.77
# (en, Nordic)                  0.82              -0.18             -0.18
# (it, Hispanic)                2.00               1.94              1.94
# (it, Indian)                  1.38               0.50              0.48
# (it, Italian)                 0.30              -0.35             -0.45
# (it, Jewish)                  1.56               1.04              0.93
#
#                 ('de', 'Germanic')  ('de', 'Jewish')  ('de', 'Muslim')  \
# (de, Africans)                1.21              1.33              1.67
# (de, British)                -0.12              0.91              0.28
# (de, French)                  0.65              1.66              1.04
# (de, Germanic)                1.00              0.60             -0.19
# (de, Jewish)                  1.80              1.00              1.67
# (de, Muslim)                  1.02              1.67              1.00
# (en, Africans)                0.18              0.86              0.16
# (en, British)                -1.00             -0.21             -0.71
# (en, EastAs)                  0.19              1.00              0.67
# (en, EastEu)                 -0.52             -0.00             -0.39
# (en, French)                 -0.69             -0.10             -0.44
# (en, Germanic)               -0.89             -0.31             -0.54
# (en, Hispanic)               -0.24              0.34             -0.25
# (en, Indian)                 -0.52              0.62             -0.11
# (en, Italian)                -0.90             -0.17             -0.76
# (en, Japanese)                0.43              1.45              0.74
# (en, Jewish)                 -0.66              0.08             -0.56
# (en, Muslim)                 -0.48              0.31             -0.29
# (en, Nordic)                  0.20              0.92              0.43
# (it, Hispanic)                1.98              2.00              2.00
# (it, Indian)                  0.69              1.66              0.99
# (it, Italian)                -0.26              0.66             -0.20
# (it, Jewish)                  1.19              1.78              1.33
#
#                 ('en', 'Africans')  ('en', 'British')  ('en', 'EastAs')  \
# (de, Africans)                1.75               1.49              1.17
# (de, British)                 0.14              -0.44              0.40
# (de, French)                  1.12               0.48              1.38
# (de, Germanic)                0.11              -0.37             -0.18
# (de, Jewish)                  2.00               1.63              1.83
# (de, Muslim)                  1.29               1.13              1.50
# (en, Africans)                1.00              -0.20              0.32
# (en, British)                -0.91               1.00             -0.55
# (en, EastAs)                  0.62               0.46              1.00
# (en, EastEu)                 -0.68              -0.98             -0.09
# (en, French)                 -0.57              -1.04             -0.32
# (en, Germanic)               -1.05              -1.48             -0.54
# (en, Hispanic)               -0.16              -0.76              0.25
# (en, Indian)                 -0.03              -0.62              0.11
# (en, Italian)                -0.63              -1.34             -0.31
# (en, Japanese)                0.68               0.21              1.03
# (en, Jewish)                 -0.35              -0.98             -0.04
# (en, Muslim)                 -0.46              -0.93             -0.15
# (en, Nordic)                  0.22              -0.23              0.65
# (it, Hispanic)                2.00               1.97              2.00
# (it, Indian)                  1.06               0.55              1.21
# (it, Italian)                -0.08              -0.38              0.25
# (it, Jewish)                  1.43               1.04              1.67
#
#                 ('en', 'EastEu')        ...         ('en', 'Indian')  \
# (de, Africans)              1.76        ...                     1.37
# (de, British)              -0.14        ...                    -0.48
# (de, French)                0.82        ...                     0.34
# (de, Germanic)             -0.09        ...                    -0.65
# (de, Jewish)                1.63        ...                     1.69
# (de, Muslim)                1.24        ...                     0.96
# (en, Africans)             -0.19        ...                    -0.10
# (en, British)              -1.19        ...                    -1.39
# (en, EastAs)                0.71        ...                     0.35
# (en, EastEu)                1.00        ...                    -0.90
# (en, French)               -0.88        ...                    -0.96
# (en, Germanic)             -1.36        ...                    -1.28
# (en, Hispanic)             -0.58        ...                    -0.56
# (en, Indian)               -0.34        ...                     1.00
# (en, Italian)              -1.10        ...                    -1.37
# (en, Japanese)              0.45        ...                     0.10
# (en, Jewish)               -0.84        ...                    -1.04
# (en, Muslim)               -0.61        ...                    -0.91
# (en, Nordic)               -0.12        ...                    -0.19
# (it, Hispanic)              1.96        ...                     1.92
# (it, Indian)                0.71        ...                     0.31
# (it, Italian)              -0.43        ...                    -0.55
# (it, Jewish)                1.20        ...                     1.06
#
#                 ('en', 'Italian')  ('en', 'Japanese')  ('en', 'Jewish')  \
# (de, Africans)               1.61                1.53              1.50
# (de, British)               -0.45               -0.44             -0.31
# (de, French)                 0.45                0.43              0.42
# (de, Germanic)              -0.39               -0.48             -0.39
# (de, Jewish)                 1.54                1.74              1.55
# (de, Muslim)                 0.95                1.03              0.91
# (en, Africans)              -0.05               -0.17             -0.01
# (en, British)               -1.47               -1.34             -1.35
# (en, EastAs)                 0.57                0.49              0.60
# (en, EastEu)                -1.01               -0.89             -0.99
# (en, French)                -0.88               -0.90             -0.93
# (en, Germanic)              -1.36               -1.21             -1.22
# (en, Hispanic)              -0.63               -0.67             -0.69
# (en, Indian)                -0.72               -0.68             -0.64
# (en, Italian)                1.00               -1.19             -1.36
# (en, Japanese)               0.24                1.00              0.17
# (en, Jewish)                -1.12               -1.01              1.00
# (en, Muslim)                -0.94               -0.87             -0.81
# (en, Nordic)                -0.16               -0.11             -0.15
# (it, Hispanic)               1.90                2.00              1.98
# (it, Indian)                 0.50                0.48              0.56
# (it, Italian)               -0.31               -0.45             -0.37
# (it, Jewish)                 0.90                1.02              0.87
#
#                 ('en', 'Muslim')  ('en', 'Nordic')  ('it', 'Hispanic')  \
# (de, Africans)              1.68              1.56                2.00
# (de, British)              -0.32             -0.26                1.12
# (de, French)                0.66              0.56                1.94
# (de, Germanic)             -0.25             -0.27                0.78
# (de, Jewish)                1.74              1.66                2.00
# (de, Muslim)                1.14              1.17                2.00
# (en, Africans)             -0.17             -0.18                0.86
# (en, British)              -1.34             -1.33                0.13
# (en, EastAs)                0.45              0.56                1.17
# (en, EastEu)               -0.81             -1.01                0.32
# (en, French)               -0.72             -0.94                0.32
# (en, Germanic)             -1.21             -1.36               -0.07
# (en, Hispanic)             -0.45             -0.67                0.66
# (en, Indian)               -0.55             -0.52                0.85
# (en, Italian)              -1.22             -1.13                0.18
# (en, Japanese)              0.27              0.34                1.71
# (en, Jewish)               -0.86             -0.88                0.50
# (en, Muslim)                1.00             -0.74                0.49
# (en, Nordic)               -0.05              1.00                1.22
# (it, Hispanic)              1.92              1.96                1.00
# (it, Indian)                0.60              0.45                1.86
# (it, Italian)              -0.29             -0.43                0.75
# (it, Jewish)                1.08              1.14                1.78
#
#                 ('it', 'Indian')  ('it', 'Italian')  ('it', 'Jewish')
# (de, Africans)              1.38               1.46              1.56
# (de, British)              -0.31              -0.00              0.23
# (de, French)                0.48               0.71              0.93
# (de, Germanic)             -0.52              -0.30             -0.01
# (de, Jewish)                1.66               1.83              1.78
# (de, Muslim)                0.99               0.97              1.33
# (en, Africans)             -0.08              -0.05              0.30
# (en, British)              -1.29              -1.05             -0.80
# (en, EastAs)                0.38               0.58              0.83
# (en, EastEu)               -0.92              -0.90             -0.44
# (en, French)               -0.92              -0.74             -0.55
# (en, Germanic)             -1.30              -1.06             -0.80
# (en, Hispanic)             -0.63              -0.64             -0.42
# (en, Indian)               -0.76              -0.45             -0.01
# (en, Italian)              -1.22              -0.86             -0.81
# (en, Japanese)              0.19               0.42              0.73
# (en, Jewish)               -0.91              -0.68             -0.61
# (en, Muslim)               -0.83              -0.55             -0.35
# (en, Nordic)               -0.29              -0.00              0.40
# (it, Hispanic)              1.86               1.91              1.78
# (it, Indian)                1.00               0.59              1.09
# (it, Italian)              -0.58               1.00              0.05
# (it, Jewish)                1.09               1.21              1.00
#
# [23 rows x 23 columns]
# ('userinfo_language', 'Gender') binary
#                ('de', 'female')  ('de', 'male')  ('de', 'not_set')  \
# (de, female)               1.00           -0.02               0.37
# (de, male)                -0.11            1.00               0.32
# (de, not_set)              0.14            0.17               1.00
# (en, female)              -0.98           -0.83              -0.41
# (en, male)                -1.11           -0.84              -0.40
# (en, not_set)             -0.71           -0.80              -0.09
# (it, female)               0.02            0.23               0.34
# (it, male)                -0.70           -0.57               0.04
#
#                ('en', 'female')  ('en', 'male')  ('en', 'not_set')  \
# (de, female)              -0.26           -0.39              -0.18
# (de, male)                -0.19           -0.21              -0.35
# (de, not_set)              0.09            0.08               0.21
# (en, female)               1.00           -1.06              -0.93
# (en, male)                -1.05            1.00              -0.93
# (en, not_set)             -0.74           -0.75               1.00
# (it, female)              -0.00            0.01               0.14
# (it, male)                -0.70           -0.70              -0.66
#
#                ('it', 'female')  ('it', 'male')
# (de, female)               0.24           -0.26
# (de, male)                 0.37           -0.21
# (de, not_set)              0.34            0.26
# (en, female)              -0.51           -0.99
# (en, male)                -0.48           -0.98
# (en, not_set)             -0.17           -0.76
# (it, female)               1.00            0.02
# (it, male)                -0.20            1.00
# ('userinfo_language', 'dateofbirth_cat') binary
#                  ('de', '1939-1969')  ('de', '1969-1979')  \
# (de, 1939-1969)                 1.00                -0.26
# (de, 1969-1979)                -0.11                 1.00
# (de, 1989-1999)                -0.53                -0.47
# (de, 1999-2009)                 0.90                 0.92
# (en, 1909-1939)                -0.17                -0.10
# (en, 1939-1969)                -0.76                -0.76
# (en, 1969-1979)                -1.31                -1.27
# (en, 1979-1989)                -0.62                -0.74
# (en, 1989-1999)                -1.16                -1.17
# (en, 1999-2009)                -0.52                -0.58
# (it, 1939-1969)                -0.05                -0.10
# (it, 1969-1979)                 0.60                 0.44
# (it, 1979-1989)                 0.29                 0.24
# (it, 1989-1999)                -0.20                -0.15
#
#                  ('de', '1989-1999')  ('de', '1999-2009')  \
# (de, 1939-1969)                -0.20                 0.15
# (de, 1969-1979)                 0.01                 0.32
# (de, 1989-1999)                 1.00                 0.13
# (de, 1999-2009)                 1.21                 1.00
# (en, 1909-1939)                -0.36                 0.00
# (en, 1939-1969)                -0.56                -0.48
# (en, 1969-1979)                -1.18                -0.89
# (en, 1979-1989)                -0.44                -0.30
# (en, 1989-1999)                -1.08                -1.01
# (en, 1999-2009)                -0.41                -0.32
# (it, 1939-1969)                -0.20                 0.58
# (it, 1969-1979)                 0.73                 0.92
# (it, 1979-1989)                 0.38                 0.10
# (it, 1989-1999)                 0.00                 0.09
#
#                  ('en', '1909-1939')  ('en', '1939-1969')  \
# (de, 1939-1969)                 0.08                -0.29
# (de, 1969-1979)                 0.31                -0.14
# (de, 1989-1999)                -0.44                -0.43
# (de, 1999-2009)                 1.00                 0.73
# (en, 1909-1939)                 1.00                -0.02
# (en, 1939-1969)                -0.23                 1.00
# (en, 1969-1979)                -0.78                -1.52
# (en, 1979-1989)                -0.09                -0.91
# (en, 1989-1999)                -0.70                -1.41
# (en, 1999-2009)                -0.30                -0.72
# (it, 1939-1969)                 0.29                 0.05
# (it, 1969-1979)                 1.11                 0.41
# (it, 1979-1989)                 0.32                -0.02
# (it, 1989-1999)                 0.28                -0.36
#
#                  ('en', '1969-1979')  ('en', '1979-1989')  \
# (de, 1939-1969)                -0.34                -0.11
# (de, 1969-1979)                -0.14                -0.08
# (de, 1989-1999)                -0.54                -0.26
# (de, 1999-2009)                 0.83                 0.95
# (en, 1909-1939)                -0.06                 0.16
# (en, 1939-1969)                -1.01                -0.87
# (en, 1969-1979)                 1.00                -1.32
# (en, 1979-1989)                -0.85                 1.00
# (en, 1989-1999)                -1.46                -1.20
# (en, 1999-2009)                -0.69                -0.54
# (it, 1939-1969)                -0.04                 0.12
# (it, 1969-1979)                 0.53                 0.44
# (it, 1979-1989)                 0.12                -0.03
# (it, 1989-1999)                -0.28                -0.52
#
#                  ('en', '1989-1999')  ('en', '1999-2009')  \
# (de, 1939-1969)                -0.20                -0.24
# (de, 1969-1979)                -0.06                -0.14
# (de, 1989-1999)                -0.46                -0.46
# (de, 1999-2009)                 0.69                 0.71
# (en, 1909-1939)                 0.01                -0.27
# (en, 1939-1969)                -0.92                -0.91
# (en, 1969-1979)                -1.49                -1.38
# (en, 1979-1989)                -0.75                -0.76
# (en, 1989-1999)                 1.00                -1.28
# (en, 1999-2009)                -0.60                 1.00
# (it, 1939-1969)                 0.05                 0.06
# (it, 1969-1979)                 0.64                 0.56
# (it, 1979-1989)                 0.08                -0.10
# (it, 1989-1999)                -0.27                -0.27
#
#                  ('it', '1939-1969')  ('it', '1969-1979')  \
# (de, 1939-1969)                -0.21                -0.14
# (de, 1969-1979)                -0.11                -0.15
# (de, 1989-1999)                -0.70                -0.35
# (de, 1999-2009)                 1.17                 0.92
# (en, 1909-1939)                -0.12                 0.11
# (en, 1939-1969)                -0.58                -0.80
# (en, 1969-1979)                -1.18                -1.20
# (en, 1979-1989)                -0.56                -0.81
# (en, 1989-1999)                -1.07                -1.07
# (en, 1999-2009)                -0.38                -0.47
# (it, 1939-1969)                 1.00                 0.07
# (it, 1969-1979)                 0.66                 1.00
# (it, 1979-1989)                 0.42                 0.16
# (it, 1989-1999)                -0.25                -0.28
#
#                  ('it', '1979-1989')  ('it', '1989-1999')
# (de, 1939-1969)                 0.22                 0.07
# (de, 1969-1979)                 0.32                 0.27
# (de, 1989-1999)                -0.02                -0.06
# (de, 1999-2009)                 0.78                 1.10
# (en, 1909-1939)                 0.00                 0.30
# (en, 1939-1969)                -0.56                -0.56
# (en, 1969-1979)                -0.93                -0.98
# (en, 1979-1989)                -0.61                -0.76
# (en, 1989-1999)                -0.95                -0.95
# (en, 1999-2009)                -0.45                -0.28
# (it, 1939-1969)                 0.51                 0.19
# (it, 1969-1979)                 0.83                 0.74
# (it, 1979-1989)                 1.00                -0.17
# (it, 1989-1999)                -0.51                 1.00
# ('race', 'Gender') binary
#                      ('Africans', 'female')  ('Africans', 'not_set')  \
# (Africans, female)                     1.00                    -0.25
# (Africans, not_set)                    1.25                     1.00
# (British, female)                     -0.88                    -0.58
# (British, male)                       -0.67                    -0.07
# (British, not_set)                    -0.24                     0.22
# (EastAs, not_set)                      0.46                     0.17
# (EastEu, female)                      -0.36                    -0.33
# (EastEu, male)                        -0.32                     0.06
# (EastEu, not_set)                     -0.06                     0.58
# (French, female)                       0.54                     0.83
# (French, male)                        -0.56                     0.07
# (French, not_set)                      1.48                     2.00
# (Germanic, female)                    -0.74                    -0.29
# (Germanic, male)                      -0.90                    -0.67
# (Germanic, not_set)                    0.33                     1.00
# (Hispanic, male)                      -0.38                     0.08
# (Hispanic, not_set)                    1.21                     1.25
# (Indian, female)                       0.82                     1.24
# (Indian, male)                         0.13                    -0.12
# (Indian, not_set)                      0.90                     1.16
# (Italian, female)                     -0.43                    -0.12
# (Italian, male)                       -1.05                    -0.63
# (Italian, not_set)                    -0.59                    -0.03
# (Japanese, male)                       1.08                     1.55
# (Japanese, not_set)                    1.15                     1.44
# (Jewish, female)                       0.21                     0.72
# (Jewish, male)                        -0.61                    -0.11
# (Jewish, not_set)                      2.00                     2.00
# (Muslim, female)                       2.00                     2.00
# (Muslim, male)                        -0.28                     0.33
# (Muslim, not_set)                      0.96                     1.54
# (Nordic, male)                         1.05                     1.52
# (Nordic, not_set)                      0.08                     0.57
#
#                      ('British', 'female')  ('British', 'male')  \
# (Africans, female)                   -0.44                -0.41
# (Africans, not_set)                   1.36                 1.69
# (British, female)                     1.00                -1.09
# (British, male)                      -0.92                 1.00
# (British, not_set)                   -0.37                -0.57
# (EastAs, not_set)                     0.60                 0.60
# (EastEu, female)                     -0.74                -0.86
# (EastEu, male)                       -0.06                -0.22
# (EastEu, not_set)                     0.04                 0.04
# (French, female)                      0.23                 0.19
# (French, male)                       -0.69                -0.50
# (French, not_set)                     1.25                 1.32
# (Germanic, female)                   -0.99                -1.06
# (Germanic, male)                     -1.20                -1.42
# (Germanic, not_set)                   0.66                 0.33
# (Hispanic, male)                     -0.59                -0.82
# (Hispanic, not_set)                   1.20                 1.38
# (Indian, female)                      0.20                 0.29
# (Indian, male)                       -0.37                -0.41
# (Indian, not_set)                     0.32                 0.47
# (Italian, female)                    -0.92                -0.78
# (Italian, male)                      -1.49                -1.84
# (Italian, not_set)                   -0.78                -0.83
# (Japanese, male)                      0.57                 0.87
# (Japanese, not_set)                   0.76                 1.10
# (Jewish, female)                     -0.04                -0.09
# (Jewish, male)                       -0.84                -0.79
# (Jewish, not_set)                     1.82                 1.93
# (Muslim, female)                      1.94                 1.94
# (Muslim, male)                       -0.46                -0.74
# (Muslim, not_set)                     0.63                 0.44
# (Nordic, male)                        0.56                 0.57
# (Nordic, not_set)                    -0.42                -0.27
#
#                      ('British', 'not_set')  ('EastAs', 'not_set')  \
# (Africans, female)                    -0.26                  -0.21
# (Africans, not_set)                    1.69                   1.00
# (British, female)                     -0.84                  -0.51
# (British, male)                       -0.86                  -0.33
# (British, not_set)                     1.00                   0.30
# (EastAs, not_set)                      0.93                   1.00
# (EastEu, female)                      -0.65                   0.02
# (EastEu, male)                        -0.35                  -0.11
# (EastEu, not_set)                      0.04                   0.78
# (French, female)                       0.31                   0.71
# (French, male)                        -0.22                  -0.10
# (French, not_set)                      1.55                   1.50
# (Germanic, female)                    -0.79                  -0.12
# (Germanic, male)                      -0.84                  -1.07
# (Germanic, not_set)                    0.42                   1.00
# (Hispanic, male)                      -0.47                  -0.11
# (Hispanic, not_set)                    1.45                   1.33
# (Indian, female)                       0.66                   1.23
# (Indian, male)                         0.03                   0.14
# (Indian, not_set)                      0.82                   1.21
# (Italian, female)                     -0.62                  -0.01
# (Italian, male)                       -1.32                  -0.73
# (Italian, not_set)                    -0.85                  -0.02
# (Japanese, male)                       1.15                   1.63
# (Japanese, not_set)                    1.33                   1.39
# (Jewish, female)                       0.42                   0.90
# (Jewish, male)                        -0.70                  -0.02
# (Jewish, not_set)                      1.74                   2.00
# (Muslim, female)                       1.99                   1.83
# (Muslim, male)                        -0.70                   0.21
# (Muslim, not_set)                      0.96                   1.46
# (Nordic, male)                         1.02                   1.47
# (Nordic, not_set)                     -0.08                   0.40
#
#                      ('EastEu', 'female')  ('EastEu', 'male')  \
# (Africans, female)                  -0.02               -0.49
# (Africans, not_set)                  1.50                1.39
# (British, female)                   -0.85               -0.67
# (British, male)                     -0.79               -0.65
# (British, not_set)                  -0.29               -0.50
# (EastAs, not_set)                    1.02                0.38
# (EastEu, female)                     1.00               -0.26
# (EastEu, male)                       0.24                1.00
# (EastEu, not_set)                    0.17                0.13
# (French, female)                     0.24                0.53
# (French, male)                      -0.12               -0.33
# (French, not_set)                    1.29                1.53
# (Germanic, female)                  -0.86               -0.65
# (Germanic, male)                    -1.15               -0.76
# (Germanic, not_set)                  0.82                0.37
# (Hispanic, male)                    -0.61               -0.37
# (Hispanic, not_set)                  1.20                1.34
# (Indian, female)                     0.52                0.88
# (Indian, male)                      -0.19                0.19
# (Indian, not_set)                    0.62                1.07
# (Italian, female)                   -0.64               -0.20
# (Italian, male)                     -1.47               -0.97
# (Italian, not_set)                  -0.38               -0.70
# (Japanese, male)                     1.10                1.19
# (Japanese, not_set)                  1.16                1.35
# (Jewish, female)                     0.14                0.55
# (Jewish, male)                      -0.83               -0.34
# (Jewish, not_set)                    1.75                1.96
# (Muslim, female)                     1.95                1.99
# (Muslim, male)                      -0.15               -0.31
# (Muslim, not_set)                    1.03                1.03
# (Nordic, male)                       0.84                1.21
# (Nordic, not_set)                    0.19               -0.05
#
#                      ('EastEu', 'not_set')  ('French', 'female')  \
# (Africans, female)                   -0.60                  0.02
# (Africans, not_set)                   1.54                  1.80
# (British, female)                    -0.94                 -0.73
# (British, male)                      -0.76                 -0.60
# (British, not_set)                   -0.47                 -0.19
# (EastAs, not_set)                     0.90                  0.85
# (EastEu, female)                     -0.69                 -0.62
# (EastEu, male)                       -0.23                  0.18
# (EastEu, not_set)                     1.00                  0.46
# (French, female)                      0.45                  1.00
# (French, male)                       -0.37                 -0.08
# (French, not_set)                     1.40                  1.30
# (Germanic, female)                   -0.73                 -0.51
# (Germanic, male)                     -0.88                 -1.06
# (Germanic, not_set)                   0.40                  0.99
# (Hispanic, male)                     -0.82                 -0.33
# (Hispanic, not_set)                   1.39                  1.44
# (Indian, female)                      0.54                  0.74
# (Indian, male)                       -0.13                  0.06
# (Indian, not_set)                     0.70                  0.84
# (Italian, female)                    -0.44                 -0.45
# (Italian, male)                      -1.25                 -1.20
# (Italian, not_set)                   -0.75                 -0.46
# (Japanese, male)                      0.96                  1.06
# (Japanese, not_set)                   1.13                  1.26
# (Jewish, female)                      0.19                  0.42
# (Jewish, male)                       -0.93                 -0.59
# (Jewish, not_set)                     1.95                  0.97
# (Muslim, female)                      2.00                  2.00
# (Muslim, male)                       -0.51                 -0.19
# (Muslim, not_set)                     0.87                  1.07
# (Nordic, male)                        0.81                  1.20
# (Nordic, not_set)                    -0.02                  0.03
#
#                              ...            ('Japanese', 'male')  \
# (Africans, female)           ...                           -0.41
# (Africans, not_set)          ...                            1.55
# (British, female)            ...                           -1.38
# (British, male)              ...                           -0.89
# (British, not_set)           ...                           -0.32
# (EastAs, not_set)            ...                            0.80
# (EastEu, female)             ...                           -0.73
# (EastEu, male)               ...                           -0.14
# (EastEu, not_set)            ...                            0.00
# (French, female)             ...                            0.09
# (French, male)               ...                           -0.44
# (French, not_set)            ...                            1.05
# (Germanic, female)           ...                           -0.97
# (Germanic, male)             ...                           -1.20
# (Germanic, not_set)          ...                            0.67
# (Hispanic, male)             ...                           -0.78
# (Hispanic, not_set)          ...                            1.25
# (Indian, female)             ...                            0.29
# (Indian, male)               ...                           -0.36
# (Indian, not_set)            ...                            0.28
# (Italian, female)            ...                           -0.84
# (Italian, male)              ...                           -1.59
# (Italian, not_set)           ...                           -0.71
# (Japanese, male)             ...                            1.00
# (Japanese, not_set)          ...                            0.78
# (Jewish, female)             ...                           -0.17
# (Jewish, male)               ...                           -0.93
# (Jewish, not_set)            ...                            1.75
# (Muslim, female)             ...                            2.00
# (Muslim, male)               ...                           -0.62
# (Muslim, not_set)            ...                            0.64
# (Nordic, male)               ...                            0.64
# (Nordic, not_set)            ...                           -0.38
#
#                      ('Japanese', 'not_set')  ('Jewish', 'female')  \
# (Africans, female)                     -0.34                 -0.56
# (Africans, not_set)                     1.44                  1.45
# (British, female)                      -1.18                 -1.26
# (British, male)                        -0.66                 -1.12
# (British, not_set)                     -0.14                 -0.33
# (EastAs, not_set)                       0.56                  0.80
# (EastEu, female)                       -0.68                 -0.97
# (EastEu, male)                          0.02                 -0.05
# (EastEu, not_set)                       0.17                 -0.05
# (French, female)                        0.29                  0.17
# (French, male)                         -0.32                 -0.47
# (French, not_set)                       0.97                  1.13
# (Germanic, female)                     -0.77                 -1.19
# (Germanic, male)                       -1.07                 -1.24
# (Germanic, not_set)                     0.83                  0.43
# (Hispanic, male)                       -0.67                 -0.84
# (Hispanic, not_set)                     1.33                  1.25
# (Indian, female)                        0.41                  0.31
# (Indian, male)                         -0.18                 -0.50
# (Indian, not_set)                       0.58                  0.37
# (Italian, female)                      -0.51                 -0.89
# (Italian, male)                        -1.31                 -1.79
# (Italian, not_set)                     -0.67                 -0.69
# (Japanese, male)                        0.78                  0.55
# (Japanese, not_set)                     1.00                  0.88
# (Jewish, female)                        0.16                  1.00
# (Jewish, male)                         -0.85                 -0.96
# (Jewish, not_set)                       1.89                  1.84
# (Muslim, female)                        1.89                  2.00
# (Muslim, male)                         -0.23                 -0.52
# (Muslim, not_set)                       0.88                  0.60
# (Nordic, male)                          0.80                  0.54
# (Nordic, not_set)                      -0.13                 -0.24
#
#                      ('Jewish', 'male')  ('Jewish', 'not_set')  \
# (Africans, female)                -0.33                   0.50
# (Africans, not_set)                1.66                   2.00
# (British, female)                 -1.01                  -0.12
# (British, male)                   -0.78                   0.16
# (British, not_set)                -0.40                   0.27
# (EastAs, not_set)                  0.92                   1.17
# (EastEu, female)                  -0.89                  -0.08
# (EastEu, male)                     0.11                   0.63
# (EastEu, not_set)                 -0.12                   0.99
# (French, female)                   0.22                   0.00
# (French, male)                    -0.31                   0.44
# (French, not_set)                  1.04                   1.64
# (Germanic, female)                -0.73                   0.10
# (Germanic, male)                  -1.00                  -0.35
# (Germanic, not_set)                0.76                   1.17
# (Hispanic, male)                  -0.72                   0.26
# (Hispanic, not_set)                1.34                   1.25
# (Indian, female)                   0.41                   1.51
# (Indian, male)                    -0.34                   0.75
# (Indian, not_set)                  0.56                   1.52
# (Italian, female)                 -0.62                   0.24
# (Italian, male)                   -1.51                  -0.48
# (Italian, not_set)                -0.59                   0.23
# (Japanese, male)                   0.84                   1.75
# (Japanese, not_set)                0.93                   1.89
# (Jewish, female)                   0.08                   1.11
# (Jewish, male)                     1.00                   0.03
# (Jewish, not_set)                  1.80                   1.00
# (Muslim, female)                   1.99                   2.00
# (Muslim, male)                    -0.43                   0.50
# (Muslim, not_set)                  0.94                   1.92
# (Nordic, male)                     0.83                   1.88
# (Nordic, not_set)                  0.00                   0.63
#
#                      ('Muslim', 'female')  ('Muslim', 'male')  \
# (Africans, female)                   0.50               -0.43
# (Africans, not_set)                  2.00                1.67
# (British, female)                   -0.00               -1.06
# (British, male)                      0.17               -1.16
# (British, not_set)                   0.52               -0.83
# (EastAs, not_set)                    1.00                0.72
# (EastEu, female)                     0.12               -0.64
# (EastEu, male)                       0.66               -0.30
# (EastEu, not_set)                    1.04               -0.13
# (French, female)                     1.03                0.18
# (French, male)                       0.53               -0.36
# (French, not_set)                    1.82                1.40
# (Germanic, female)                   0.15               -0.80
# (Germanic, male)                    -0.33               -1.19
# (Germanic, not_set)                  1.33                0.46
# (Hispanic, male)                     0.25               -0.76
# (Hispanic, not_set)                  2.00                1.49
# (Indian, female)                     1.59                0.39
# (Indian, male)                       0.78               -0.22
# (Indian, not_set)                    1.65                0.42
# (Italian, female)                    0.53               -0.80
# (Italian, male)                     -0.29               -1.67
# (Italian, not_set)                   0.31               -0.96
# (Japanese, male)                     2.00                0.72
# (Japanese, not_set)                  1.89                1.11
# (Jewish, female)                     1.27                0.09
# (Jewish, male)                       0.21               -0.86
# (Jewish, not_set)                    2.00                1.84
# (Muslim, female)                     1.00                1.99
# (Muslim, male)                       0.65                1.00
# (Muslim, not_set)                    1.96                0.69
# (Nordic, male)                       1.94                0.78
# (Nordic, not_set)                    0.92               -0.26
#
#                      ('Muslim', 'not_set')  ('Nordic', 'male')  \
# (Africans, female)                   -0.54               -0.45
# (Africans, not_set)                   1.54                1.52
# (British, female)                    -1.31               -1.38
# (British, male)                      -1.32               -1.19
# (British, not_set)                   -0.51               -0.45
# (EastAs, not_set)                     0.62                0.64
# (EastEu, female)                     -0.80               -0.99
# (EastEu, male)                       -0.29               -0.12
# (EastEu, not_set)                    -0.09               -0.16
# (French, female)                      0.10                0.23
# (French, male)                       -0.60               -0.71
# (French, not_set)                     1.23                1.09
# (Germanic, female)                   -1.15               -1.15
# (Germanic, male)                     -1.38               -1.27
# (Germanic, not_set)                   0.37                0.44
# (Hispanic, male)                     -0.86               -0.93
# (Hispanic, not_set)                   1.33                1.21
# (Indian, female)                      0.15                0.03
# (Indian, male)                       -0.46               -0.49
# (Indian, not_set)                     0.34                0.29
# (Italian, female)                    -0.77               -0.89
# (Italian, male)                      -1.63               -1.74
# (Italian, not_set)                   -0.97               -0.81
# (Japanese, male)                      0.64                0.64
# (Japanese, not_set)                   0.88                0.80
# (Jewish, female)                     -0.12               -0.18
# (Jewish, male)                       -0.84               -0.95
# (Jewish, not_set)                     1.92                1.88
# (Muslim, female)                      1.96                1.94
# (Muslim, male)                       -0.65               -0.56
# (Muslim, not_set)                     1.00                0.46
# (Nordic, male)                        0.46                1.00
# (Nordic, not_set)                    -0.48               -0.43
#
#                      ('Nordic', 'not_set')
# (Africans, female)                   -0.33
# (Africans, not_set)                   1.65
# (British, female)                    -1.28
# (British, male)                      -0.95
# (British, not_set)                   -0.47
# (EastAs, not_set)                     0.65
# (EastEu, female)                     -0.56
# (EastEu, male)                       -0.29
# (EastEu, not_set)                     0.10
# (French, female)                      0.14
# (French, male)                       -0.67
# (French, not_set)                     1.11
# (Germanic, female)                   -0.87
# (Germanic, male)                     -1.24
# (Germanic, not_set)                   0.38
# (Hispanic, male)                     -0.58
# (Hispanic, not_set)                   1.18
# (Indian, female)                      0.38
# (Indian, male)                       -0.17
# (Indian, not_set)                     0.54
# (Italian, female)                    -0.68
# (Italian, male)                      -1.41
# (Italian, not_set)                   -0.87
# (Japanese, male)                      0.71
# (Japanese, not_set)                   0.95
# (Jewish, female)                      0.12
# (Jewish, male)                       -0.69
# (Jewish, not_set)                     1.71
# (Muslim, female)                      2.00
# (Muslim, male)                       -0.52
# (Muslim, not_set)                     0.60
# (Nordic, male)                        0.66
# (Nordic, not_set)                     1.00
#
# ...
# (Germanic, 1969-1979)                    -0.66                    -0.11
# (Germanic, 1979-1989)                     2.00                     2.00
# (Germanic, 1989-1999)                    -0.61                     0.23
# (Germanic, 1999-2009)                     1.14                     1.33
# (Hispanic, 1939-1969)                     1.45                     1.25
# (Hispanic, 1969-1979)                    -0.01                     0.32
# (Hispanic, 1989-1999)                     0.38                     0.75
# (Indian, 1969-1979)                      -0.17                     0.73
# (Indian, 1989-1999)                      -0.34                     0.55
# (Indian, 1999-2009)                       0.79                     1.56
# (Italian, 1939-1969)                     -1.05                    -0.16
# (Italian, 1969-1979)                     -0.66                    -0.03
# (Italian, 1979-1989)                     -0.86                    -0.21
# (Italian, 1989-1999)                     -1.45                    -0.64
# (Italian, 1999-2009)                     -0.20                     0.50
# (Japanese, 1969-1979)                     0.95                     1.67
# (Japanese, 1989-1999)                     0.85                     1.50
# (Jewish, 1939-1969)                      -0.04                     0.56
# (Jewish, 1969-1979)                       0.40                     0.80
# (Jewish, 1989-1999)                      -0.47                     0.05
# (Jewish, 1999-2009)                       0.44                     0.95
# (Muslim, 1969-1979)                       0.61                     1.06
# (Muslim, 1979-1989)                       1.59                     2.00
# (Muslim, 1989-1999)                      -0.23                     0.34
# (Muslim, 1999-2009)                       0.92                     1.75
# (Nordic, 1969-1979)                       1.00                     0.76
# (Nordic, 1979-1989)                       1.45                     1.00
# (Nordic, 1999-2009)                       1.00                     1.71
#
#                        ('Nordic', '1999-2009')
# (Africans, 1969-1979)                     1.02
# (Africans, 1979-1989)                     1.81
# (Africans, 1989-1999)                     0.43
# (British, 1909-1939)                      1.71
# (British, 1939-1969)                     -0.37
# (British, 1969-1979)                     -0.81
# (British, 1979-1989)                     -0.26
# (British, 1989-1999)                     -0.36
# (British, 1999-2009)                     -0.45
# (EastAs, 1969-1979)                       1.81
# (EastAs, 1979-1989)                       1.71
# (EastEu, 1939-1969)                       0.08
# (EastEu, 1969-1979)                       1.90
# (EastEu, 1989-1999)                      -0.66
# (French, 1939-1969)                       0.36
# (French, 1969-1979)                       1.07
# (French, 1979-1989)                       1.71
# (French, 1989-1999)                       0.49
# (Germanic, 1909-1939)                     2.00
# (Germanic, 1939-1969)                    -0.38
# (Germanic, 1969-1979)                    -0.81
# (Germanic, 1979-1989)                     2.00
# (Germanic, 1989-1999)                    -0.52
# (Germanic, 1999-2009)                     1.33
# (Hispanic, 1939-1969)                     1.71
# (Hispanic, 1969-1979)                    -0.09
# (Hispanic, 1989-1999)                     0.27
# (Indian, 1969-1979)                      -0.08
# (Indian, 1989-1999)                      -0.41
# (Indian, 1999-2009)                       0.95
# (Italian, 1939-1969)                     -0.72
# (Italian, 1969-1979)                     -0.71
# (Italian, 1979-1989)                     -1.19
# (Italian, 1989-1999)                     -1.39
# (Italian, 1999-2009)                     -0.27
# (Japanese, 1969-1979)                     0.86
# (Japanese, 1989-1999)                     0.78
# (Jewish, 1939-1969)                      -0.04
# (Jewish, 1969-1979)                       0.29
# (Jewish, 1989-1999)                      -0.64
# (Jewish, 1999-2009)                       0.26
# (Muslim, 1969-1979)                       0.40
# (Muslim, 1979-1989)                       1.43
# (Muslim, 1989-1999)                      -0.53
# (Muslim, 1999-2009)                       0.81
# (Nordic, 1969-1979)                       0.31
# (Nordic, 1979-1989)                       1.71
# (Nordic, 1999-2009)                       1.00
#
# [48 rows x 48 columns]
# ('Gender', 'dateofbirth_cat') binary
#                       ('female', '1909-1939')  ('female', '1939-1969')  \
# (female, 1909-1939)                      1.00                     1.15
# (female, 1939-1969)                      0.38                     1.00
# (female, 1969-1979)                     -0.84                    -1.50
# (female, 1979-1989)                      0.52                    -0.17
# (female, 1989-1999)                     -0.86                    -1.34
# (female, 1999-2009)                      0.39                    -0.38
# (male, 1909-1939)                        2.00                     1.79
# (male, 1939-1969)                       -0.25                    -0.96
# (male, 1969-1979)                       -0.17                    -1.05
# (male, 1979-1989)                       -0.66                    -1.06
# (male, 1989-1999)                       -0.64                    -1.65
# (male, 1999-2009)                       -0.21                    -0.37
# (not_set, 1939-1969)                     0.22                    -0.73
# (not_set, 1969-1979)                    -0.19                    -0.95
# (not_set, 1979-1989)                     0.48                     0.33
# (not_set, 1989-1999)                    -0.03                    -0.85
# (not_set, 1999-2009)                     0.42                    -0.31
#
#                       ('female', '1969-1979')  ('female', '1979-1989')  \
# (female, 1909-1939)                      1.12                     1.24
# (female, 1939-1969)                     -0.31                    -0.24
# (female, 1969-1979)                      1.00                    -1.33
# (female, 1979-1989)                     -0.08                     1.00
# (female, 1989-1999)                     -1.24                    -1.25
# (female, 1999-2009)                     -0.32                    -0.41
# (male, 1909-1939)                        1.89                     1.65
# (male, 1939-1969)                       -0.82                    -1.04
# (male, 1969-1979)                       -0.80                    -1.04
# (male, 1979-1989)                       -1.06                    -1.30
# (male, 1989-1999)                       -1.39                    -1.42
# (male, 1999-2009)                       -0.29                    -0.41
# (not_set, 1939-1969)                    -0.57                    -0.54
# (not_set, 1969-1979)                    -0.80                    -1.02
# (not_set, 1979-1989)                     0.49                     0.47
# (not_set, 1989-1999)                    -0.71                    -0.57
# (not_set, 1999-2009)                    -0.04                    -0.16
#
#                       ('female', '1989-1999')  ('female', '1999-2009')  \
# (female, 1909-1939)                      0.95                     1.28
# (female, 1939-1969)                     -0.30                    -0.27
# (female, 1969-1979)                     -1.39                    -1.39
# (female, 1979-1989)                     -0.15                    -0.23
# (female, 1989-1999)                      1.00                    -1.10
# (female, 1999-2009)                     -0.18                     1.00
# (male, 1909-1939)                        1.87                     1.49
# (male, 1939-1969)                       -1.07                    -0.86
# (male, 1969-1979)                       -0.93                    -1.04
# (male, 1979-1989)                       -1.14                    -1.01
# (male, 1989-1999)                       -1.33                    -1.45
# (male, 1999-2009)                       -0.41                    -0.21
# (not_set, 1939-1969)                    -0.53                    -0.52
# (not_set, 1969-1979)                    -0.90                    -0.84
# (not_set, 1979-1989)                     0.38                     0.44
# (not_set, 1989-1999)                    -0.67                    -0.59
# (not_set, 1999-2009)                    -0.26                     0.01
#
#                       ('male', '1909-1939')  ('male', '1939-1969')  \
# (female, 1909-1939)                    2.00                   1.19
# (female, 1939-1969)                    1.01                  -0.31
# (female, 1969-1979)                   -0.07                  -1.35
# (female, 1979-1989)                    0.93                  -0.32
# (female, 1989-1999)                    0.05                  -1.45
# (female, 1999-2009)                    0.61                  -0.31
# (male, 1909-1939)                      1.00                   1.80
# (male, 1939-1969)                      0.36                   1.00
# (male, 1969-1979)                      0.18                  -0.97
# (male, 1979-1989)                      0.14                  -1.16
# (male, 1989-1999)                     -0.20                  -1.47
# (male, 1999-2009)                      0.89                  -0.38
# (not_set, 1939-1969)                   0.71                  -0.69
# (not_set, 1969-1979)                   0.18                  -1.04
# (not_set, 1979-1989)                   1.37                   0.52
# (not_set, 1989-1999)                   0.59                  -0.63
# (not_set, 1999-2009)                   1.10                  -0.27
#
#                       ('male', '1969-1979')  ('male', '1979-1989')  \
# (female, 1909-1939)                    1.28                   1.03
# (female, 1939-1969)                   -0.37                  -0.15
# (female, 1969-1979)                   -1.31                  -1.33
# (female, 1979-1989)                   -0.29                  -0.32
# (female, 1989-1999)                   -1.29                  -1.26
# (female, 1999-2009)                   -0.48                  -0.20
# (male, 1909-1939)                      1.63                   1.83
# (male, 1939-1969)                     -0.95                  -0.90
# (male, 1969-1979)                      1.00                  -0.77
# (male, 1979-1989)                     -1.01                   1.00
# (male, 1989-1999)                     -1.48                  -1.28
# (male, 1999-2009)                     -0.22                  -0.35
# (not_set, 1939-1969)                  -0.67                  -0.43
# (not_set, 1969-1979)                  -1.04                  -0.74
# (not_set, 1979-1989)                   0.35                   0.47
# (not_set, 1989-1999)                  -0.68                  -0.58
# (not_set, 1999-2009)                  -0.31                   0.01
#
#                       ('male', '1989-1999')  ('male', '1999-2009')  \
# (female, 1909-1939)                    1.31                   0.88
# (female, 1939-1969)                   -0.47                  -0.06
# (female, 1969-1979)                   -1.41                  -1.16
# (female, 1979-1989)                   -0.18                  -0.03
# (female, 1989-1999)                   -1.20                  -1.13
# (female, 1999-2009)                   -0.39                  -0.01
# (male, 1909-1939)                      1.74                   1.98
# (male, 1939-1969)                     -0.96                  -0.72
# (male, 1969-1979)                     -0.99                  -0.59
# (male, 1979-1989)                     -1.02                  -0.95
# (male, 1989-1999)                      1.00                  -1.13
# (male, 1999-2009)                     -0.27                   1.00
# (not_set, 1939-1969)                  -0.71                  -0.24
# (not_set, 1969-1979)                  -0.96                  -0.63
# (not_set, 1979-1989)                   0.33                   0.26
# (not_set, 1989-1999)                  -0.90                  -0.50
# (not_set, 1999-2009)                  -0.22                  -0.02
#
#                       ('not_set', '1939-1969')  ('not_set', '1969-1979')  \
# (female, 1909-1939)                       1.41                      1.33
# (female, 1939-1969)                      -0.32                     -0.21
# (female, 1969-1979)                      -1.34                     -1.25
# (female, 1979-1989)                      -0.07                     -0.22
# (female, 1989-1999)                      -1.16                     -1.21
# (female, 1999-2009)                      -0.22                     -0.21
# (male, 1909-1939)                         1.90                      1.69
# (male, 1939-1969)                        -0.93                     -0.96
# (male, 1969-1979)                        -0.93                     -0.98
# (male, 1979-1989)                        -0.94                     -0.92
# (male, 1989-1999)                        -1.47                     -1.40
# (male, 1999-2009)                        -0.15                     -0.21
# (not_set, 1939-1969)                      1.00                     -0.73
# (not_set, 1969-1979)                     -1.05                      1.00
# (not_set, 1979-1989)                      0.41                      0.42
# (not_set, 1989-1999)                     -0.79                     -0.64
# (not_set, 1999-2009)                     -0.32                     -0.33
#
#                       ('not_set', '1979-1989')  ('not_set', '1989-1999')  \
# (female, 1909-1939)                       1.11                      1.28
# (female, 1939-1969)                       0.18                     -0.31
# (female, 1969-1979)                      -0.84                     -1.36
# (female, 1979-1989)                       0.39                      0.03
# (female, 1989-1999)                      -0.80                     -1.17
# (female, 1999-2009)                       0.18                     -0.16
# (male, 1909-1939)                         2.00                      1.90
# (male, 1939-1969)                        -0.28                     -0.75
# (male, 1969-1979)                        -0.47                     -0.82
# (male, 1979-1989)                        -0.59                     -0.96
# (male, 1989-1999)                        -0.98                     -1.54
# (male, 1999-2009)                        -0.20                     -0.28
# (not_set, 1939-1969)                     -0.15                     -0.66
# (not_set, 1969-1979)                     -0.46                     -0.83
# (not_set, 1979-1989)                      1.00                      0.17
# (not_set, 1989-1999)                     -0.52                      1.00
# (not_set, 1999-2009)                      0.09                     -0.22
#
#                       ('not_set', '1999-2009')
# (female, 1909-1939)                       1.14
# (female, 1939-1969)                      -0.36
# (female, 1969-1979)                      -1.28
# (female, 1979-1989)                      -0.15
# (female, 1989-1999)                      -1.35
# (female, 1999-2009)                      -0.15
# (male, 1909-1939)                         1.82
# (male, 1939-1969)                        -0.98
# (male, 1969-1979)                        -1.04
# (male, 1979-1989)                        -0.95
# (male, 1989-1999)                        -1.45
# (male, 1999-2009)                        -0.38
# (not_set, 1939-1969)                     -0.78
# (not_set, 1969-1979)                     -1.12
# (not_set, 1979-1989)                      0.19
# (not_set, 1989-1999)                     -0.81
# (not_set, 1999-2009)                      1.00
